# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://data.oecd.org/energy/renewable-energy.htm#indicator-chart'
html = requests.get(url).content
html
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n<meta charset="utf-8">\r\n<title>Energy - Renewable energy - OECD Data</title>\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\r\n<meta name="referrer" content="always">\r\n<meta name="description" content="Renewable energy is defined as the contribution of renewables to total primary energy supply." />\n\r\n<meta name="keywords" content="energy; renewables; primary; supply; hydro; geothermal; solar; wind; tide:wave; biofuel; biogasoline; biodiesel; biogas; waste; climate change; global warming; fossil fuel; sustainable; source; power; force" />\n  \r\n<script type="text/javascript">\r\n  var languageSwitch = \'<a href="">\xe2\x80\xba </a><a href="/fr/energy/energies-renouvelables.htm">Fran&ccedil;ais</a><!--<a href="/energy/renewable-energy.htm">English</a>-->\';\r\n</script>\r\n<script>\r\ndataLayer = [{\r\n\t\'siteName\':"data",\r
# ...

# %%
sp = BeautifulSoup(html, 'html.parser')
sp
print(sp.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Energy - Renewable energy - OECD Data
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
#   <meta content="always" name="referrer"/>
#   <meta content="Renewable energy is defined as the contribution of renewables to total primary energy supply." name="description">
#    <meta content="energy; renewables; primary; supply; hydro; geothermal; solar; wind; tide:wave; biofuel; biogasoline; biodiesel; biogas; waste; climate change; global warming; fossil fuel; sustainable; source; power; force" name="keywords">
#     <script type="text/javascript">
#      var languageSwitch = '<a href="">› </a><a href="/fr/energy/energies-renouvelables.htm">Fran&ccedil;ais</a><!--<a href="/energy/renewable-energy.htm">English</a>-->';
#     </script>
#     <script>
#      dataLayer = [{
# ...

# %%
# selector =  'a'
selector =  'div.multiple-table-scroll-wrapper'

# %%
sp.select(selector)
# Out:
# []

# %%
table = sp.find_all("a")
table
# Out:
# [<a class="oecd-header__link" href="http://oecd.org/">OECD.org</a>,
#  <a class="oecd-header__link" href="http://www.oecd-ilibrary.org/">Publications</a>,
#  <a class="oecd-header__link oecd-header__secondary-toggle" href="">More sites</a>,
#  <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecdbetterlifeindex.org/">OECD Better Life Index</a>,
#  <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd-ilibrary.org/">OECD iLibrary</a>,
#  <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecdobserver.org/">OECD Observer</a>,
#  <a class="oecd-header__link oecd-header__secondary-link" href="http://oecdinsights.org/">OECD Insights blog</a>,
#  <a class="oecd-header__link oecd-header__secondary-link" href="http://www.oecd.org/dev/">OECD Development Centre</a>,
#  <a class="oecd-header__link oecd-header__secondary-link" href="http://www.fatf-gafi.org/">FATF - Financial Action Task Force</a>,
# ...
